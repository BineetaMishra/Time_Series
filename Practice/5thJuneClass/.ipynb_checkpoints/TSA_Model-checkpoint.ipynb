# %%
import pandas as pd

# %% [markdown]
# # Importing Data

# %%
df= pd.read_csv('air_pollution.csv',parse_dates=['date'])

# %%
df.set_index('date',inplace=True)

# %% [markdown]
# # Checking the data is loaded

# %%
df.head()
# Out:
#             pollution_today        dew       temp        press     wnd_spd  \
# date
# 2010-01-02       145.958333  -8.500000  -5.125000  1024.750000   24.860000
# 2010-01-03        78.833333 -10.125000  -8.541667  1022.791667   70.937917
# 2010-01-04        31.333333 -20.875000 -11.500000  1029.291667  111.160833
# 2010-01-05        42.458333 -24.583333 -14.458333  1033.625000   56.920000
# 2010-01-06        56.416667 -23.708333 -12.541667  1033.750000   18.511667
#
#                  snow  rain  pollution_yesterday
# date
# 2010-01-02   0.708333   0.0            10.041667
# 2010-01-03  14.166667   0.0           145.958333
# 2010-01-04   0.000000   0.0            78.833333
# 2010-01-05   0.000000   0.0            31.333333
# 2010-01-06   0.000000   0.0            42.458333

# %%
df.tail()
# Out:
#             pollution_today        dew      temp        press     wnd_spd  \
# date
# 2014-12-27       238.666667  -9.666667 -1.791667  1027.833333    9.278333
# 2014-12-28       197.375000 -10.791667  1.583333  1019.958333   10.948750
# 2014-12-29       159.000000 -12.333333  0.750000  1013.750000    8.000000
# 2014-12-30        46.083333 -13.916667  1.875000  1019.125000    9.778333
# 2014-12-31        10.041667 -21.791667 -1.916667  1032.125000  167.458333
#
#             snow  rain  pollution_yesterday
# date
# 2014-12-27   0.0   0.0           170.250000
# 2014-12-28   0.0   0.0           238.666667
# 2014-12-29   0.0   0.0           197.375000
# 2014-12-30   0.0   0.0           159.000000
# 2014-12-31   0.0   0.0            46.083333

# %%
df_new= df['pollution_today']

# %%
df_new.head()
# Out:
# date
# 2010-01-02    145.958333
# 2010-01-03     78.833333
# 2010-01-04     31.333333
# 2010-01-05     42.458333
# 2010-01-06     56.416667
# Name: pollution_today, dtype: float64

# %%
import matplotlib.pyplot as plt

# %%
df_new.plot()

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
from pylab import rcParams

# %%
decompose= seasonal_decompose(df_new,model='additive')
rcParams['figure.figsize']=10,5
decompose.plot();

# %% [markdown]
# # Plotting PACF and ACF

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
fig, (ax1, ax2) = plt.subplots(1, 2,figsize=(16,6), dpi= 80)
plot_acf(df_new.tolist(), ax=ax1, lags=50);
plot_pacf(df_new.tolist(), ax=ax2, lags=20);

# %%
from statsmodels.tsa.statespace.tools import diff

# %%
# create a differenced series
def difference(dataset, interval=1):
    diff = list()
    for i in range(interval, len(dataset)):
        value = dataset[i] - dataset[i - interval]
        diff.append(value)
    return diff

# %%
# difference the dataset
diff1 = difference(df_new, interval=1)
plt.plot(diff1)

# %%
fig, (ax1, ax2) = plt.subplots(1, 2,figsize=(16,6), dpi= 80)
plot_acf(diff1, ax=ax1, lags=50);
plot_pacf(diff1, ax=ax2, lags=20);

# %%
# difference the dataset
diff2 = difference(diff1, interval=365)
plt.plot(diff2)

# %%
fig, (ax1, ax2) = plt.subplots(1, 2,figsize=(16,6), dpi= 80)
plot_acf(diff2, ax=ax1, lags=50);
plot_pacf(diff2, ax=ax2, lags=20);

# %%
# difference the dataset
diff3 = difference(diff2, interval=365)
plt.plot(diff3)

# %%
fig, (ax1, ax2) = plt.subplots(1, 2,figsize=(16,6), dpi= 80)
plot_acf(diff3, ax=ax1, lags=50);
plot_pacf(diff3, ax=ax2, lags=20);
