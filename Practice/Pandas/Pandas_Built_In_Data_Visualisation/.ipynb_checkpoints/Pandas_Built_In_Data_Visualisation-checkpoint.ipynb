# %%
import pandas as pd
# Onle for Jupyter users
# %matplotlib inline

# %%
df1 = pd.read_csv('df1.csv',index_col=0)

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df2 = pd.read_csv('df2.csv')

# %%
df2.head()
# Out:
#           a         b         c         d  e
# 0  0.039762  0.218517  0.103423  0.957904  x
# 1  0.937288  0.041567  0.899125  0.977680  y
# 2  0.780504  0.008948  0.557808  0.797510  x
# 3  0.672717  0.247870  0.264071  0.444358  z
# 4  0.053829  0.520124  0.552264  0.190008  y

# %% [markdown]
# # HISTOGRAMS

# %%
df1['A'].plot.hist()

# %%
df1['A'].plot.hist(edgecolor='k')

# %%
df1['A'].plot.hist(edgecolor='k').autoscale(enable=True,axis='both',tight=True)

# %%
df1['A'].plot.hist(bins=20,edgecolor='k').autoscale(enable=True,axis='both',tight=True)

# %% [markdown]
# # Barplots

# %%
df2.plot.bar()

# %%
df2.plot.bar(stacked=True)

# %%
df2.plot.barh()

# %% [markdown]
# # LinePlots

# %%
df2.plot.line(y='a')

# %%
df2.plot.line(y='a',figsize=(10,4))

# %%
df2.plot.line(y='a',figsize=(10,4),lw=4)

# %%
df2.plot.line(y=['a','b','c'],figsize=(10,4),lw=4)

# %%
df1.plot.line()

# %% [markdown]
# # Area Plots
#
# ### Very Similar to line plots only that it represents cummilatively stacked line plots

# %%
df2.plot.area()

# %%
df2.plot.area(alpha=0.4)

# %%
df2.plot.area(stacked=False,alpha=0.4)

# %% [markdown]
# # Scatter plots .
#
# ### Used to quickly compare 2 variables.

# %%
df1
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436
# ...              ...       ...       ...       ...
# 2002-09-22  1.013897 -0.288680 -0.342295 -0.638537
# 2002-09-23 -0.642659 -0.104725 -0.631829 -0.909483
# 2002-09-24  0.370136  0.233219  0.535897 -1.552605
# 2002-09-25  0.183339  1.285783 -1.052593 -2.565844
# 2002-09-26  0.775133 -0.850374  0.486728 -1.053427
#
# [1000 rows x 4 columns]

# %%
df1.plot.scatter(x='A',y='B')

# %%
df1.plot.scatter(x='A',y='B',c='C')

# %%
df1.plot.scatter(x='A',y='B',c='D')

# %%
df1.plot.scatter(x='A',y='B',c='C',cmap='coolwarm')

# %%
df1.plot.scatter(x='A',y='B',c='C',cmap='coolwarm',s=df1['C'])
# Out:
# C:\Users\ebineet\Anaconda3\lib\site-packages\matplotlib\collections.py:857: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %%
df1.plot.scatter(x='A',y='B',c='C',cmap='coolwarm',s=df1['C']*50)

# %% [markdown]
# # box Plot

# %%
df2
# Out:
#           a         b         c         d  e
# 0  0.039762  0.218517  0.103423  0.957904  x
# 1  0.937288  0.041567  0.899125  0.977680  y
# 2  0.780504  0.008948  0.557808  0.797510  x
# 3  0.672717  0.247870  0.264071  0.444358  z
# 4  0.053829  0.520124  0.552264  0.190008  y
# 5  0.286043  0.593465  0.907307  0.637898  x
# 6  0.430436  0.166230  0.469383  0.497701  z
# 7  0.312296  0.502823  0.806609  0.850519  z
# 8  0.187765  0.997075  0.895955  0.530390  x
# 9  0.908162  0.232726  0.414138  0.432007  y

# %%
df2.plot.box()

# %%
df2.boxplot()

# %% [markdown]
# # kernel Density Estimation plot (KDE)

# %%
df2.plot.kde()

# %%
df1.plot.kde()

# %%
import numpy as np
df = pd.DataFrame(np.random.randn(100,2),columns=['a','b'])

# %%
df
# Out:
#            a         b
# 0  -0.778590  1.145233
# 1  -1.980060  1.114609
# 2  -1.588331 -0.255623
# 3  -0.064956 -0.825361
# 4   0.363898  0.767708
# ..       ...       ...
# 95  0.571424  0.829819
# 96  0.877047  0.276332
# 97 -0.186511  0.974379
# 98 -0.059689 -1.166696
# 99 -0.257500  1.327641
#
# [100 rows x 2 columns]

# %%
df.plot.scatter(x='a',y='b')

# %% [markdown]
# # HEXBIN Plot

# %%
df.plot.hexbin(x='a',y='b')

# %%
df.plot.hexbin(x='a',y='b',gridsize=25)

# %%
df.plot.hexbin(x='a',y='b',gridsize=25,cmap='coolwarm')
